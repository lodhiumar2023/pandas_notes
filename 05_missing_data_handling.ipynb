# %% [markdown]
# # Working with Missing Data

# %%
import pandas as pd

# %%
data = pd.read_excel("missing_data.xlsx")
data
# Out:
#    Order_Number          Customer_Name Order_Date     Status  \
# 0        139374            Adhir Samal 2020-01-11  Delivered
# 1        139375         Dannana Jhammi 2020-01-11  Delivered
# 2        139376            Vipin Kumar 2020-01-11  Delivered
# 3        139377          Ranjeet Kumar 2020-01-11  Delivered
# 4        139378          Sajal Singhal 2020-01-11      Order
# 5        139379         Akhilesh Kumar 2020-01-11      Order
# 6        139380   Suvankar Chakraborty 2020-01-11      Order
# 7        139381      Suvankar Adhikary 2020-01-12      Order
# 8        139382  Rahul Kumar Prajapati 2020-01-13      Order
#
#                     Product      Category     Brand    Cost  Sales  Quantity  \
# 0                512 GB M.2           SSD   Samsung  6500.0   8450         1
# 1      RYZEN 3rd gen. 3500            CPU     Intel     NaN  11050         3
# 2          2GB Graphic Card  Graphic Card    Nvidia  7000.0   9100         2
# 3            16 GB DDR4 RAM           RAM     Hynix  6550.0   8515         3
# 4  Standard ATX motherboard   MotherBoard  Gigabyte     NaN   9945         4
# 5        Compact with 1 Fan       Cabinet      Asus  1150.0   1495         2
# 6    USB Backlight Keyboard      Keyboard      Dell     NaN   1105         3
# 7           Ergonomic Mouse         Mouse   Samsung   650.0    845         2
# 8           15" LCD Dsipaly       Monitor      Dell     NaN   9750         1
#
#    Total_Cost  Total_Sales
# 0        6500         8450
# 1       25500        33150
# 2       14000        18200
# 3       19650        25545
# 4       30600        39780
# 5        2300         2990
# 6        2550         3315
# 7        1300         1690
# 8        7500         9750

# %%
data.isnull().sum()
# Out:
# Order_Number     0
# Customer_Name    0
# Order_Date       0
# Status           0
# Product          0
# Category         0
# Brand            0
# Cost             4
# Sales            0
# Quantity         0
# Total_Cost       0
# Total_Sales      0
# dtype: int64

# %% [markdown]
# #### To drop all null values

# %%
data.dropna()
# Out:
#    Order_Number      Customer_Name Order_Date     Status             Product  \
# 0        139374        Adhir Samal 2020-01-11  Delivered          512 GB M.2
# 2        139376        Vipin Kumar 2020-01-11  Delivered    2GB Graphic Card
# 3        139377      Ranjeet Kumar 2020-01-11  Delivered      16 GB DDR4 RAM
# 5        139379     Akhilesh Kumar 2020-01-11      Order  Compact with 1 Fan
# 7        139381  Suvankar Adhikary 2020-01-12      Order     Ergonomic Mouse
#
#        Category    Brand    Cost  Sales  Quantity  Total_Cost  Total_Sales
# 0           SSD  Samsung  6500.0   8450         1        6500         8450
# 2  Graphic Card   Nvidia  7000.0   9100         2       14000        18200
# 3           RAM    Hynix  6550.0   8515         3       19650        25545
# 5       Cabinet     Asus  1150.0   1495         2        2300         2990
# 7         Mouse  Samsung   650.0    845         2        1300         1690

# %% [markdown]
# #### To fill all null values

# %%
import numpy as np

# %%
data.replace(np.nan, "python")
# Out:
#    Order_Number          Customer_Name Order_Date     Status  \
# 0        139374            Adhir Samal 2020-01-11  Delivered
# 1        139375         Dannana Jhammi 2020-01-11  Delivered
# 2        139376            Vipin Kumar 2020-01-11  Delivered
# 3        139377          Ranjeet Kumar 2020-01-11  Delivered
# 4        139378          Sajal Singhal 2020-01-11      Order
# 5        139379         Akhilesh Kumar 2020-01-11      Order
# 6        139380   Suvankar Chakraborty 2020-01-11      Order
# 7        139381      Suvankar Adhikary 2020-01-12      Order
# 8        139382  Rahul Kumar Prajapati 2020-01-13      Order
#
#                     Product      Category     Brand    Cost  Sales  Quantity  \
# 0                512 GB M.2           SSD   Samsung  6500.0   8450         1
# 1      RYZEN 3rd gen. 3500            CPU     Intel  python  11050         3
# 2          2GB Graphic Card  Graphic Card    Nvidia  7000.0   9100         2
# 3            16 GB DDR4 RAM           RAM     Hynix  6550.0   8515         3
# 4  Standard ATX motherboard   MotherBoard  Gigabyte  python   9945         4
# 5        Compact with 1 Fan       Cabinet      Asus  1150.0   1495         2
# 6    USB Backlight Keyboard      Keyboard      Dell  python   1105         3
# 7           Ergonomic Mouse         Mouse   Samsung   650.0    845         2
# 8           15" LCD Dsipaly       Monitor      Dell  python   9750         1
#
#    Total_Cost  Total_Sales
# 0        6500         8450
# 1       25500        33150
# 2       14000        18200
# 3       19650        25545
# 4       30600        39780
# 5        2300         2990
# 6        2550         3315
# 7        1300         1690
# 8        7500         9750

# %% [markdown]
# #### To fill null numeric values by column

# %%
data["Cost"] = data["Cost"].replace(np.nan,4370.0)
data
# Out:
#    Order_Number          Customer_Name Order_Date     Status  \
# 0        139374            Adhir Samal 2020-01-11  Delivered
# 1        139375         Dannana Jhammi 2020-01-11  Delivered
# 2        139376            Vipin Kumar 2020-01-11  Delivered
# 3        139377          Ranjeet Kumar 2020-01-11  Delivered
# 4        139378          Sajal Singhal 2020-01-11      Order
# 5        139379         Akhilesh Kumar 2020-01-11      Order
# 6        139380   Suvankar Chakraborty 2020-01-11      Order
# 7        139381      Suvankar Adhikary 2020-01-12      Order
# 8        139382  Rahul Kumar Prajapati 2020-01-13      Order
#
#                     Product      Category     Brand    Cost  Sales  Quantity  \
# 0                512 GB M.2           SSD   Samsung  6500.0   8450         1
# 1      RYZEN 3rd gen. 3500            CPU     Intel  4370.0  11050         3
# 2          2GB Graphic Card  Graphic Card    Nvidia  7000.0   9100         2
# 3            16 GB DDR4 RAM           RAM     Hynix  6550.0   8515         3
# 4  Standard ATX motherboard   MotherBoard  Gigabyte  4370.0   9945         4
# 5        Compact with 1 Fan       Cabinet      Asus  1150.0   1495         2
# 6    USB Backlight Keyboard      Keyboard      Dell  4370.0   1105         3
# 7           Ergonomic Mouse         Mouse   Samsung   650.0    845         2
# 8           15" LCD Dsipaly       Monitor      Dell  4370.0   9750         1
#
#    Total_Cost  Total_Sales
# 0        6500         8450
# 1       25500        33150
# 2       14000        18200
# 3       19650        25545
# 4       30600        39780
# 5        2300         2990
# 6        2550         3315
# 7        1300         1690
# 8        7500         9750

# %% [markdown]
# #### To find the mean value in numeric data

# %%
data["Cost"].mean()
# Out:
# 4370.0

# %% [markdown]
# #### Fill null value by backward fill

# %%
data.fillna(method="ffill")
# Out:
# C:\Users\onlin\AppData\Local\Temp\ipykernel_18208\2321864255.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method="ffill")
#    Order_Number          Customer_Name Order_Date     Status  \
# 0        139374            Adhir Samal 2020-01-11  Delivered
# 1        139375         Dannana Jhammi 2020-01-11  Delivered
# 2        139376            Vipin Kumar 2020-01-11  Delivered
# 3        139377          Ranjeet Kumar 2020-01-11  Delivered
# 4        139378          Sajal Singhal 2020-01-11      Order
# 5        139379         Akhilesh Kumar 2020-01-11      Order
# 6        139380   Suvankar Chakraborty 2020-01-11      Order
# 7        139381      Suvankar Adhikary 2020-01-12      Order
# 8        139382  Rahul Kumar Prajapati 2020-01-13      Order
#
#                     Product      Category     Brand    Cost  Sales  Quantity  \
# 0                512 GB M.2           SSD   Samsung  6500.0   8450         1
# 1      RYZEN 3rd gen. 3500            CPU     Intel  6500.0  11050         3
# 2          2GB Graphic Card  Graphic Card    Nvidia  7000.0   9100         2
# 3            16 GB DDR4 RAM           RAM     Hynix  6550.0   8515         3
# 4  Standard ATX motherboard   MotherBoard  Gigabyte  6550.0   9945         4
# 5        Compact with 1 Fan       Cabinet      Asus  1150.0   1495         2
# 6    USB Backlight Keyboard      Keyboard      Dell  1150.0   1105         3
# 7           Ergonomic Mouse         Mouse   Samsung   650.0    845         2
# 8           15" LCD Dsipaly       Monitor      Dell   650.0   9750         1
#
#    Total_Cost  Total_Sales
# 0        6500         8450
# 1       25500        33150
# 2       14000        18200
# 3       19650        25545
# 4       30600        39780
# 5        2300         2990
# 6        2550         3315
# 7        1300         1690
# 8        7500         9750

# %% [markdown]
# #### Fill null value by forward fill

# %%
data.fillna(method="bfill")
# Out:
# C:\Users\onlin\AppData\Local\Temp\ipykernel_18208\1981131366.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method="bfill")
#    Order_Number          Customer_Name Order_Date     Status  \
# 0        139374            Adhir Samal 2020-01-11  Delivered
# 1        139375         Dannana Jhammi 2020-01-11  Delivered
# 2        139376            Vipin Kumar 2020-01-11  Delivered
# 3        139377          Ranjeet Kumar 2020-01-11  Delivered
# 4        139378          Sajal Singhal 2020-01-11      Order
# 5        139379         Akhilesh Kumar 2020-01-11      Order
# 6        139380   Suvankar Chakraborty 2020-01-11      Order
# 7        139381      Suvankar Adhikary 2020-01-12      Order
# 8        139382  Rahul Kumar Prajapati 2020-01-13      Order
#
#                     Product      Category     Brand    Cost  Sales  Quantity  \
# 0                512 GB M.2           SSD   Samsung  6500.0   8450         1
# 1      RYZEN 3rd gen. 3500            CPU     Intel  7000.0  11050         3
# 2          2GB Graphic Card  Graphic Card    Nvidia  7000.0   9100         2
# 3            16 GB DDR4 RAM           RAM     Hynix  6550.0   8515         3
# 4  Standard ATX motherboard   MotherBoard  Gigabyte  1150.0   9945         4
# 5        Compact with 1 Fan       Cabinet      Asus  1150.0   1495         2
# 6    USB Backlight Keyboard      Keyboard      Dell   650.0   1105         3
# 7           Ergonomic Mouse         Mouse   Samsung   650.0    845         2
# 8           15" LCD Dsipaly       Monitor      Dell     NaN   9750         1
#
#    Total_Cost  Total_Sales
# 0        6500         8450
# 1       25500        33150
# 2       14000        18200
# 3       19650        25545
# 4       30600        39780
# 5        2300         2990
# 6        2550         3315
# 7        1300         1690
# 8        7500         9750
