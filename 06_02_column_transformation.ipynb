# %% [markdown]
# # Columns Transformation

# %%
import pandas as pd

# %% [markdown]
# ### Calculated Column

# %%
data = pd.read_excel('columns_transformation.xlsx')
data['Total_Sale'] = (data['Sales'] * data['Quantity'])
data['Discount'] = data['Total_Sale'] / 100 * 2
data
# Out:
#    Order_Number          Customer_Name Order_Date     Status  \
# 0        139374            Adhir Samal 2020-01-11  Delivered
# 1        139375         Dannana Jhammi 2020-01-11  Delivered
# 2        139376            Vipin Kumar 2020-01-11  Delivered
# 3        139377          Ranjeet Kumar 2020-01-11  Delivered
# 4        139378          Sajal Singhal 2020-01-11      Order
# 5        139379         Akhilesh Kumar 2020-01-11      Order
# 6        139380   Suvankar Chakraborty 2020-01-11      Order
# 7        139381      Suvankar Adhikary 2020-01-12      Order
# 8        139382  Rahul Kumar Prajapati 2020-01-13      Order
#
#                     Product      Category     Brand  Cost  Sales  Quantity  \
# 0                512 GB M.2           SSD   Samsung  6500   8450         1
# 1      RYZEN 3rd gen. 3500            CPU     Intel  8500  11050         3
# 2          2GB Graphic Card  Graphic Card    Nvidia  7000   9100         2
# ...

# %%
data = pd.read_excel('columns_transformation.xlsx')
data
# Out:
#    Order_Number          Customer_Name Order_Date      Month     Status  \
# 0        139374            Adhir Samal 2020-01-11    January  Delivered
# 1        139375         Dannana Jhammi 2020-02-11   February  Delivered
# 2        139376            Vipin Kumar 2020-03-11      March  Delivered
# 3        139377          Ranjeet Kumar 2020-04-11      April  Delivered
# 4        139378          Sajal Singhal 2020-05-11        May      Order
# 5        139379         Akhilesh Kumar 2020-06-11       June      Order
# 6        139380   Suvankar Chakraborty 2020-07-11       July      Order
# 7        139381      Suvankar Adhikary 2020-08-12     August      Order
# 8        139382  Rahul Kumar Prajapati 2020-09-13  September      Order
#
#                     Product      Category     Brand  Cost  Sales  Quantity
# 0                512 GB M.2           SSD   Samsung  6500   8450         1
# 1      RYZEN 3rd gen. 3500            CPU     Intel  8500  11050         3
# ...

# %% [markdown]
# ### Extracting a column data using map function.

# %%
def extract(value):
    return value[0:3]


data["Short_Month"] = data["Month"].map(extract)
data
# Out:
#    Order_Number          Customer_Name Order_Date      Month     Status  \
# 0        139374            Adhir Samal 2020-01-11    January  Delivered
# 1        139375         Dannana Jhammi 2020-02-11   February  Delivered
# 2        139376            Vipin Kumar 2020-03-11      March  Delivered
# 3        139377          Ranjeet Kumar 2020-04-11      April  Delivered
# 4        139378          Sajal Singhal 2020-05-11        May      Order
# 5        139379         Akhilesh Kumar 2020-06-11       June      Order
# 6        139380   Suvankar Chakraborty 2020-07-11       July      Order
# 7        139381      Suvankar Adhikary 2020-08-12     August      Order
# 8        139382  Rahul Kumar Prajapati 2020-09-13  September      Order
#
#                     Product      Category     Brand  Cost  Sales  Quantity  \
# 0                512 GB M.2           SSD   Samsung  6500   8450         1
# 1      RYZEN 3rd gen. 3500            CPU     Intel  8500  11050         3
# ...
